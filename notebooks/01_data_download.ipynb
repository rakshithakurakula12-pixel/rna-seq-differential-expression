# %% [markdown]
# # RNA-Seq Differential Expression Pipeline
# ### Step 1: Download dataset from GEO
#
# This notebook downloads the RNA-Seq dataset from GEO.

# %%
# !pip install GEOparse

# %%
import GEOparse

# Example dataset: GSE183947 (You can change later)
gse = GEOparse.get_GEO(geo="GSE183947", destdir="../data")
gse
